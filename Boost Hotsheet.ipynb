# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = 8, 5
sns.set_style('darkgrid')

# %%
from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2>{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %%
phones_df = pd.read_csv('hotsheet.csv')
phones_df.head()
# Out:
#               Name  SRP  New/Upgrade  Port-In  Port-In (60)  BoostUp! (Down)  \
# 0  Coolpad Belleza   60           30       30            30              NaN
# 1      Wiki Ride 3  100           60        0             0              NaN
# 2     Samsung A02s  110           60        0             0              NaN
# 3      Moto G Play  130           60        0             0              NaN
# 4           LG K51  150          100        0             0              NaN
#
#    BoostUp! (Monthly)
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
phones_df["Name"] = phones_df["Name"].str.lower()
phones_df
# Out:
#                   Name   SRP  New/Upgrade  Port-In  Port-In (60)  \
# 0      coolpad belleza    60           30       30            30
# 1          wiki ride 3   100           60        0             0
# 2         samsung a02s   110           60        0             0
# 3          moto g play   130           60        0             0
# 4               lg k51   150          100        0             0
# 5          moto g fast   150          100        0             0
# 6        coolpad brisa   160           80        0             0
# 7         moto g power   170          150        0             0
# 8        moto g stylus   180          180        0             0
# 9          samsung a12   180          100        0             0
# 10          lg stylo 6   220          180        0             0
# 11         samsung a21   250          180        0             0
# 12    moto g stylus 5g   250          200      100           100
# ...

# %%
phones_df['SRP Price with Activation'] = phones_df['SRP'] + 35
phones_df[['Name', 'SRP Price with Activation']]
# Out:
#                   Name  SRP Price with Activation
# 0      Coolpad Belleza                         95
# 1          Wiki Ride 3                        135
# 2         Samsung A02s                        145
# 3          Moto G Play                        165
# 4               LG K51                        185
# 5          Moto G Fast                        185
# 6        Coolpad Brisa                        195
# 7         Moto G Power                        205
# 8        Moto G Stylus                        215
# 9          Samsung A12                        215
# 10          LG Stylo 6                        255
# 11         Samsung A21                        285
# 12    Moto G Stylus 5G                        285
# 13      Samsung A32 5G                        315
# 14         Samsung A51                        435
# 15   iPhone 8 Re-Newed                        285
# 16  iPhone XR Re-Newed                        385
# 17           iPhone SE                        435
# ...

# %%
phones_df['New/Upgrade Price with Activation'] = phones_df['SRP'] + 25
phones_df[['Name', 'New/Upgrade Price with Activation']]
# Out:
#                   Name  New/Upgrade Price with Activation
# 0      Coolpad Belleza                                 85
# 1          Wiki Ride 3                                125
# 2         Samsung A02s                                135
# 3          Moto G Play                                155
# 4               LG K51                                175
# 5          Moto G Fast                                175
# 6        Coolpad Brisa                                185
# 7         Moto G Power                                195
# 8        Moto G Stylus                                205
# 9          Samsung A12                                205
# 10          LG Stylo 6                                245
# 11         Samsung A21                                275
# 12    Moto G Stylus 5G                                275
# 13      Samsung A32 5G                                305
# 14         Samsung A51                                425
# ...

# %%
phones_df['Port-In Price with Activation'] = phones_df['Port-In'] + 25
phones_df[['Name', 'Port-In Price with Activation']]
# Out:
#                   Name  Port-In Price with Activation
# 0      Coolpad Belleza                             55
# 1          Wiki Ride 3                             25
# 2         Samsung A02s                             25
# 3          Moto G Play                             25
# 4               LG K51                             25
# 5          Moto G Fast                             25
# 6        Coolpad Brisa                             25
# 7         Moto G Power                             25
# 8        Moto G Stylus                             25
# 9          Samsung A12                             25
# 10          LG Stylo 6                             25
# 11         Samsung A21                             25
# 12    Moto G Stylus 5G                            125
# 13      Samsung A32 5G                            125
# 14         Samsung A51                            255
# 15   iPhone 8 Re-Newed                             75
# ...

# %%
phones_df['Port-In ($60) Price with Activation'] = phones_df['Port-In (60)'] + 25
phones_df[['Name', 'Port-In ($60) Price with Activation']]
# Out:
#                   Name  Port-In ($60) Price with Activation
# 0      Coolpad Belleza                                   55
# 1          Wiki Ride 3                                   25
# 2         Samsung A02s                                   25
# 3          Moto G Play                                   25
# 4               LG K51                                   25
# 5          Moto G Fast                                   25
# 6        Coolpad Brisa                                   25
# 7         Moto G Power                                   25
# 8        Moto G Stylus                                   25
# 9          Samsung A12                                   25
# 10          LG Stylo 6                                   25
# 11         Samsung A21                                   25
# 12    Moto G Stylus 5G                                  125
# 13      Samsung A32 5G                                  125
# 14         Samsung A51                                  155
# ...

# %%
phones_df['Port-In ($60) Price with Activation'] = phones_df['Port-In (60)'] + 25
phones_df[['Name', 'Port-In ($60) Price with Activation']]
# Out:
#                   Name  Port-In ($60) Price with Activation
# 0      Coolpad Belleza                                   55
# 1          Wiki Ride 3                                   25
# 2         Samsung A02s                                   25
# 3          Moto G Play                                   25
# 4               LG K51                                   25
# 5          Moto G Fast                                   25
# 6        Coolpad Brisa                                   25
# 7         Moto G Power                                   25
# 8        Moto G Stylus                                   25
# 9          Samsung A12                                   25
# 10          LG Stylo 6                                   25
# 11         Samsung A21                                   25
# 12    Moto G Stylus 5G                                  125
# 13      Samsung A32 5G                                  125
# 14         Samsung A51                                  155
# ...
